# %%
print("ola mundo")
# Out:
# ola mundo

# %% [markdown]
# **Operação Aritimetica**

# %%
# Adição
10 + 2
# Out:
# 12

# %%
# Subtração
10 - 2
# Out:
# 8

# %%
# Multiplicação
10 * 3
# Out:
# 30

# %%
# Divisão
10 / 2
# Out:
# 5.0

# %%
# Divisão :Inteira
10 // 2
# Out:
# 5

# %%
# Resto de Divisão
10 % 2
# Out:
# 0

# %%
# Resto de Potenciação
10 ** 2
# Out:
# 100

# %%
# Operadores Relacionais
1 < 2
# Out:
# True
