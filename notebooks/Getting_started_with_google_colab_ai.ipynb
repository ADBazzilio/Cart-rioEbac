# %% [markdown]
# Operações Aritimetica

# %%
print("ola mundo")
# Out:
# ola mundo

# %%
# Adição
10 + 2
# Out:
# 12

# %%
# Subtração
10 - 2
# Out:
# 8

# %%
# Multiplicação
10 * 3
# Out:
# 30

# %%
# Divisão
10 / 2
# Out:
# 5.0

# %%
# Divisão :Inteira
10 // 2
# Out:
# 5

# %%
# Resto de Divisão
10 % 2
# Out:
# 0

# %%
# Resto de Potenciação
10 ** 2
# Out:
# 100

# %% [markdown]
# Operadores Relacionado

# %%
# Menor
1 < 2  # True Verdadeiro
# Out:
# True

# %%
# Menor ou igual
1 <= 10  # <= ( menor ou igual) True Verdadeiro
# Out:
# True

# %%
# Maior
2 > 1   # >  ( Maior)  True Verdadeiro
# Out:
# True

# %%
# Maior ou igual
2 >= 2   #   >= (Maior ou igual)  Tru Verdadeiro
# Out:
# True

# %%
# Igual
5 == 5   # == (Igual)
# Out:
# True

# %%
# Diferente

5 != 8     #  !=  (Diferente)
# Out:
# True

# %% [markdown]
# • And = (E)
#
# • Or = (O)
#
# • Not = (Não)

# %% [markdown]
# And   = E

# %%
2 > 1 and 5 < 8  # True and True
# Out:
# True

# %%
2 > 1 and 5 > 8  # True and False
# Out:
# False

# %%
2 < 1 and 5 < 8  # False and True
# Out:
# False

# %%
2 < 1 and 5 > 8  # False and False
# Out:
# False

# %% [markdown]
# • Or = (O)

# %%
2 > 1 or 5 < 8   # True or True True

# %%
2 > 1 or 5 > 8  # True or False
# Out:
# True

# %%
2 < 1 or 5 < 8  # False or True True
# Out:
# True

# %%
2 < 1 or 5 > 8 #False or False
# Out:
# False

# %% [markdown]
# NoT  = (Não)

# %%
not 2 > 1 # True
# Out:
# False

# %%
not 1 < 2 # False
# Out:
# False
